# %%
import pandas as pd
from matplotlib import pyplot as plt

turizm = pd.read_excel("turizm_rev.xlsx")
turizm
# Out:
#    year   total   women     men  azerbaijan  azeri_women  azeri_men  \
# 0  2015  1917.7  1056.1   861.6         2.9          0.8        2.1
# 1  2016  2027.0  1128.3   898.7         2.4          0.6        1.8
# 2  2017  2690.0  1496.5  1193.5         3.8          0.8        3.0
# 3  2018  5346.3  2830.5  2515.8        10.4          2.1        8.3
# 4  2019  6748.5  3530.0  3218.5        12.4          2.6        9.8
# 5  2020  1504.1   738.7   765.4         2.2          0.5        1.7
# 6  2021  1881.4   924.6   956.7         2.9          0.6        2.3
#
#    afghanistan  afghan_women  afghan_men  ...  ukr_men  france  fran_women  \
# 0         18.4           1.9        16.5  ...    1.800    3.50        1.90
# 1         19.2           1.9        17.3  ...    0.600    4.70        2.60
# 2         23.4           2.4        21.0  ...    0.700    5.60        3.20
# 3         44.2           8.3        35.9  ...    7.600   13.50        6.90
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
turizm = pd.read_excel("turizm_rev.xlsx")
turizm
df = pd.DataFrame(turizm)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
W = list(df.iloc[:, 2])
S = list(df.iloc[:, 3])


plt.plot(X, Y, color='blue', label='total')
plt.plot(X, W, color='red', label='women')
plt.plot(X, S, color='black', label='men')
plt.legend(fontsize=8)

plt.xticks(rotation = 0)
plt.title("Arrivals of foreign citizents to the Republic of Uzbekistan")
plt.xlabel("YEARS")
plt.ylabel("Total arrivals of foreign citizens")

 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
turizm = pd.read_excel("turizm_rev.xlsx")
turizm
df = pd.DataFrame(turizm)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

plt.step(X, Y, color='blue', label="Total arrivals of foreign citizens")
plt.legend(fontsize=8)

plt.xticks(rotation = 0)
plt.title("Arrivals of foreign citizents to the Republic of Uzbekistan")
plt.xlabel("YEARS")

  
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

safar = pd.read_excel("chet_safar.xlsx")
safar
# Out:
#    year  total   rest and leisure  medical treatment  visit to relatives  \
# 0  2012  1895.0             181.8               77.7              1528.7
# 1  2013  1968.6             154.8               92.4              1581.7
# 2  2014  1862.0             156.0               85.4              1475.1
# 3  2015  1917.7             166.8               55.7              1555.7
# 4  2016  2027.0             175.5               27.1              1651.2
# 5  2017  2690.0             203.7               28.7              2272.4
# 6  2018  5346.3             458.1               52.5              4713.5
# 7  2019  6748.5            1043.9               55.6              5520.7
# 8  2020  1504.1             129.3               15.0              1321.4
# 9  2021  1881.4             155.1               32.4              1613.1
#
#    studies  business  commerce
# 0      5.6      81.8      19.2
# 1      7.5     104.7      27.6
# 2      9.7     108.0      27.8
# 3     10.3     113.7      15.4
# ...

# %%
df = pd.DataFrame(safar)
X = list(df.iloc[:, 0])
R = list(df.iloc[:, 2])
M = list(df.iloc[:, 3])
V = list(df.iloc[:, 4])
S = list(df.iloc[:, 5])
B = list(df.iloc[:, 6])
C = list(df.iloc[:, 7])
  
plt.scatter(X, R, color='yellow', label='rest and leisure')
plt.scatter(X, M, color='orange', label='medical treatment')
plt.scatter(X, V, color='blue', label='visit to relatives')
plt.scatter(X, S, color='red', label='studies')
plt.scatter(X, B, color='tan', label='business')
plt.scatter(X, C, color='c', label='commerce')
plt.legend(fontsize=8)

plt.xticks(rotation = 0)
plt.title("Arrivals of foreign citizents to the Republic of Uzbekistan")
plt.xlabel("YEAR")
plt.ylabel("Total arrivals of foreign citizens")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


category_names = ['rest and leisure', 'medical treatment',
                  'visit to relatives', 'studies', 'business', 'commerce']
results = {
    '2012': [9.6, 4.1, 80.7, 0.3, 4.3, 1.0],
    '2013': [7.9, 4.7, 80.3, 0.4, 5.3, 1.4],
    '2014': [8.4, 4.6, 79.2, 0.5, 5.8, 1.5],
    '2015': [8.7, 2.9, 81.1, 0.6, 5.9, 0.8],
    '2016': [8.7, 1.3, 81.5, 0.3, 7.4, 0.8],
    '2017': [7.6, 1.1, 84.5, 0.2, 5.9, 0.7],
    '2018': [8.6, 1.0, 88.2, 0.3, 1.0, 0.9],
    '2019': [15.5, 0.8, 81.8, 0.3, 0.8, 0.8],
    '2020': [8.6, 1.0, 87.9, 0.3, 1.2, 1.1],
    '2021': [8.2, 1.7, 85.7, 0.3, 3.2, 0.7],
}

def survey(results, category_names):
   
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 6))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.8,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = '0' if r * g * b < 0.9 else 'darkgrey'
        
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 0),
              loc='lower left', fontsize='small')
    return fig, ax
        
survey(results, category_names)

plt.xticks(rotation = 0)
plt.title("Arrivals of foreign citizents to the Republic of Uzbekistan, %")
plt.ylabel("YEARS")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['2015-y', '2016-y', '2017-y', '2018-y', '2019-y', '2020-y', '2021-y']
men_means = [861.6, 898.7, 1193.5, 2515.8, 3218.5, 765.4, 956.7]
women_means = [1056.1, 1128.3, 1496.5, 2830.5, 3530.0, 738.7, 924.6]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='erkaklar')
rects2 = ax.bar(x + width/2, women_means, width, label='ayollar')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('kelgan chet el fuqarolari')
ax.set_title('Turistik maqsadlarda O‘zbekiston Respublikasiga kelgan chet el fuqarolari soni, ming kishi')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


year = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
population_by_continent = {
    'Buyuk Britaniya': [1.8, 2, 3, 7.9, 15.9, 1.4, 4],
    'AQSH': [1.2, 1.1, 1.3, 11.1, 17.1, 1.8, 5.4],
    'Janubiy Koreya': [25.7, 25.3, 31.1, 27.3, 35.5, 6.7, 5.8],
    'Germaniya': [5.5, 5.9, 7.3, 18.1, 27.6, 2.1, 6.9],
    'Hindiston': [18.1, 17.9, 15.2, 21, 27.9, 4.7, 10.7],
    'Turkiya': [36.3, 39.7, 48.3, 41.3, 63.5, 21, 44.2],
    'Rossiya': [113.3, 106.9, 130.0, 371.6, 455.5, 81.6, 190.5],
    'Tojikiston': [212.4, 169.0, 206.6, 1095.5, 1473.7, 337.5, 288.3],
    'Qozog‘iston': [1250.8, 1384.3, 1752.2, 2293.1, 2261.0, 424.1, 565.3],
    'Qirg‘iziston': [139.8, 168.1, 366.1, 1055.7, 1454.9, 508.1, 652.2],
}

fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys(), alpha=0.8)
ax.legend(loc='upper left')
ax.set_title('O‘zbekiston Respublikasiga kelgan chet el fuqarolarining davlatlar bo‘yicha taqsimlanishi, ming kishi')
ax.set_xlabel('Yillar')
ax.set_ylabel('kelgan chet el fuqarolari soni')

plt.show()

# %%
import matplotlib.pyplot as plt 
 
 
labels = ['bo‘sh vaqt va dam olish', 'davolanish', 'qarindoshlarni yo‘qlash', 'o‘qish', 'xizmat yuzasidan', 'tijorat'] 
men_means = [109.9, 13.9, 169.1, 4.9, 51.3, 7.6] 
women_means = [45.2, 18.5, 144.0, 1.5, 9.4, 6.1] 
 
width = 0.65       # the width of the bars: can also be len(x) sequence 
 
fig, ax = plt.subplots() 
 
ax.bar(labels, men_means, width, label='erkalar') 
ax.bar(labels, women_means, width,bottom=men_means, label='ayollar') 
plt.xticks(rotation='vertical') 
 
ax.set_ylabel('chet ellik turistlar') 
ax.set_title('O`zbekiston Respublikasiga turistik maqsadlarda kelgan chet el fuqarolarining safar maqsadlari bo‘yicha taqsimlanishi, ming kishi') 
ax.legend() 
 
plt.show()

# %%
import matplotlib.pyplot as plt


labels = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
men_means = [1432.1, 1707.2, 1600.6, 2071.4, 2280.4, 2995.6, 4209, 4087.6, 1085.2, 1187.4]
women_means = [1279, 1438.2, 1185.3, 1432.9, 1567.4, 2186.9, 4385.8, 4350.3, 916.3, 1007.4]
men_std = [2, 3, 4, 1, 2, 3, 4, 1, 2, 2]
women_std = [3, 5, 2, 3, 3, 5, 2, 3, 3, 3]
width = 0.65       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='erkaklar')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='ayollar')


ax.set_ylabel('Turistik maqsadlarda ketgan O‘zbekiston fuqarolari')
ax.set_title('Turistik maqsadlarda chet elga ketgan O‘zbekiston Respublikasi fuqarolari soni, ming kishi')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

maqsadlar = ['Bo‘sh vaqt va dam olish', 'Davolanish', 'Qarindoshlarni yo‘qlash', 'O‘qish', 'Xizmat yuzasidan']
soni = [349.2, 23.9, 617.1, 189.1, 15.6]

bar_colors = ['tab:green', 'tab:blue', 'tab:red', 'tab:orange', 'tab:pink']

ax.bar(maqsadlar, soni, color=bar_colors)
plt.xticks(rotation='vertical') 

ax.set_ylabel('Turistlar soni')
ax.set_xlabel('safar maqsadlari')
ax.set_title('Turistik maqsadlarda chet elga ketgan O‘zbekiston Respublikasi fuqarolari soni, ming kishi')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = {'Qirg‘iziston': 409.3,
        'Qozog‘iston': 301.1,
        'Tojikiston': 182.5,
        'Turkiya': 174.0,
        'Rossiya': 168.6,
        'BAA': 77.7,
        'Janubiy Koreya': 7.7,
        'AQSH': 6.8,
        'Belarusiya': 6.3,
        'Hindiston': 4.5}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

fig, ax = plt.subplots()
ax.barh(group_names, group_data)

ax.set_title('Turistik maqsadlarda chet elga ketgan O‘zbekiston fuqarolari davlatlar bo‘yicha')
ax.set_xlabel('Turistlar soni')
plt.show()
